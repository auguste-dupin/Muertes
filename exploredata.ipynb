# %%
# Config
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import pyreadstat
import os

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
archivos = os.listdir('./data/sav/')
df = pd.DataFrame()
for archivo in archivos:
    name = str(archivo)[2:].split('2')[0].replace('_','').strip()

    archivo_df, meta = pyreadstat.read_sav(f'./data/sav/{archivo}', apply_value_formats=True)
    archivo_df.columns = meta.column_labels
    archivo_df['Muerte'] = name

    
    print(f'Leyendo {name}')

    if 'Calificación de la muerte' in archivo_df.columns:
        archivo_df['Calificación muerte 1'] = archivo_df['Calificación de la muerte'].iloc[:,0]
        archivo_df['Calificación muerte 2'] = archivo_df['Calificación de la muerte'].iloc[:,1]
        archivo_df = archivo_df.drop(['Calificación de la muerte'], axis=1)

    df = pd.concat([df, archivo_df])

df
# Out:
# Leyendo ACCIDENTES DE TRANSITOS
# Leyendo AHOGAMIENTOS
# Leyendo ELECTROCUCIONES
# Leyendo HOMICIDIOS
# Leyendo MUERTES EN ACCIDENTES
# Leyendo SUICIDIOS
#      Día de la semana        Mes Año de ocurrencia  \
# 0               Lunes      Enero            2007.0
# 1               Lunes      Enero            2007.0
# 2               Lunes      Enero            2007.0
# 3               Lunes      Enero            2007.0
# 4               Lunes      Enero            2007.0
# ...               ...        ...               ...
# 8082            Lunes  Diciembre               NaN
# 8083        Miércoles  Diciembre               NaN
# 8084        Miércoles  Diciembre               NaN
# 8085           Jueves  Diciembre               NaN
# 8086           Jueves  Diciembre               NaN
#
#      Rango de hora de ocurrencia                 Región             Provincia  \
# 0                    18:01-20:00               Valdesia               Peravia
# ...

# %%
def limpiar(df):
    temp = df['Año']

    df['Año'] = np.where(df[df['Muerte'] == ''])

# %%
def histogram(df, x, color=None):
    df = df.copy()
    df['count'] = 1

    if color:
        df = df.groupby(by=[x, color]).sum().reset_index()

        fig = px.bar(
            df,
            x = x,
            y = 'count',
            color = color,
        )
    else:
        df = df.groupby(by=[x]).sum().reset_index()

        fig = px.bar(
            df,
            x = x,
            y = 'count',
            # trendline='lowess',
            # trendline_scope="overall",
        )

    fig.show()

# histogram(df[df['Muerte'] == 'ACCIDENTES DE TRANSITOS'], 'Año de ocurrencia', 'Medio de tránsporte en que viajaba')
histogram(df, 'Año', 'Muerte')
# Out:
# <div>                            <div id="143ccc5b-2784-4f7d-8558-67f92b628aea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("143ccc5b-2784-4f7d-8558-67f92b628aea")) {                    Plotly.newPlot(                        "143ccc5b-2784-4f7d-8558-67f92b628aea",                        [{"alignmentgroup":"True","hovertemplate":"Medio de tr\u00e1nsporte en que viajaba=Ambulancia<br>A\u00f1o de ocurrencia=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Ambulancia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ambulancia","offsetgroup":"Ambulancia","orientation":"v","showlegend":true,"textposition":"auto","x":[2007.0,2008.0,2009.0,2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0],"xaxis":"x","y":[0,0,0,1,
# ...

# %%
histogram(df[df['Muerte'] == 'ACCIDENTES DE TRANSITOS'], 'Año de ocurrencia', 'Medio de tránsporte en que viajaba')
# Out:
# <div>                            <div id="83f510bf-a831-4128-ac2b-5591900a184c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83f510bf-a831-4128-ac2b-5591900a184c")) {                    Plotly.newPlot(                        "83f510bf-a831-4128-ac2b-5591900a184c",                        [{"alignmentgroup":"True","hovertemplate":"Medio de tr\u00e1nsporte en que viajaba=Ambulancia<br>A\u00f1o de ocurrencia=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Ambulancia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ambulancia","offsetgroup":"Ambulancia","orientation":"v","showlegend":true,"textposition":"auto","x":[2007.0,2008.0,2009.0,2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0],"xaxis":"x","y":[0,0,0,1,
# ...
